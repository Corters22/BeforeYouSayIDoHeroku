# %%
from sklearn import tree
import pandas as pd
import os

# %%
df = pd.read_csv(os.path.join('..','divorce_data.csv'),sep=";")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#    Q1  Q2  Q3  Q4  Q5  Q6  Q7  Q8  Q9  Q10  ...  Q46  Q47  Q48  Q49  Q50  Q51  \
# 0   2   2   4   1   0   0   0   0   0    0  ...    2    1    3    3    3    2
# 1   4   4   4   4   4   0   0   4   4    4  ...    2    2    3    4    4    4
# 2   2   2   2   2   1   3   2   1   1    2  ...    3    2    3    1    1    1
# 3   3   2   3   2   3   3   3   3   3    3  ...    2    2    3    3    3    3
# 4   2   2   1   1   1   1   0   0   0    0  ...    2    1    2    3    2    2
#
#    Q52  Q53  Q54  Divorce
# 0    3    2    1        1
# 1    4    2    2        1
# 2    2    2    2        1
# 3    2    2    2        1
# 4    2    1    0        1
#
# [5 rows x 55 columns]

# %%
target = df["Divorce"]
data = df.drop("Divorce", axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.8837209302325582

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.9767441860465116

# %%
question_data = pd.read_csv('../reference.tsv', delimiter='|')
question_data
# Out:
#     atribute_id                                        description
# 0             1  If one of us apologizes when our discussion de...
# 1             2  I know we can ignore our differences, even if ...
# 2             3  When we need it, we can take our discussions f...
# 3             4  When I discuss with my spouse, to contact him ...
# 4             5  The time I spend with my spouse is special for...
# 5             6            We don't have time at home as partners.
# 6             7  We are like two strangers who share the same e...
# 7             8               I enjoy our holidays with my spouse.
# 8             9                  I enjoy traveling with my spouse.
# 9            10        Most of my goals are common with my spouse.
# 10           11  I think that one day in the future, when I loo...
# 11           12  My spouse and I have similar values in terms o...
# 12           13  My spouse and I have a similar sense of entert...
# 13           14  Most of our goals for people (children, friend...
# 14           15  My dreams with my spouse are similar and harmo...
# 15           16  I'm compatible with my spouse about what love ...
# 16           17  We share the same views about being happy in o...
# 17           18  My spouse and I have similar ideas about how m...
# 18           19  My spouse and I have similar ideas about how r...
# 19           20      My spouse and I have similar values in trust.
# 20           21               I know exactly what my spouse likes.
# 21           22  I know how my spouse wants to be taken care of...
# 22           23                  I know my spouse's favorite food.
# 23           24  I can tell you what kind of stress my spouse i...
# 24           25       I have knowledge of my spouse's inner world.
# 25           26                I know my spouse's basic anxieties.
# 26           27  I know what my spouse's current sources of str...
# 27           28               I know my spouse's hopes and wishes.
# 28           29                        I know my spouse very well.
# 29           30  I know my spouse's friends and their social re...
# 30           31     I feel aggressive when I argue with my spouse.
# 31           32  When discussing problems with my spouse, I usu...
# 32           33  I use negative statements about my spouse's pe...
# 33           34  I use offensive expressions during our discuss...
# 34           35         I insult my spouse during our discussions.
# 35           36          I can be humiliating when we discussions.
# 36           37        My discussions with my spouse are not calm.
# 37           38       I hate my spouse's way of opening a subject.
# 38           39              Our discussions often occur suddenly.
# 39           40  We're just starting a discussion before I know...
# 40           41  When I talk to my spouse about something, my c...
# 41           42  When I argue with my spouse, I only go out and...
# 42           43  I mostly stay silent to calm the environment a...
# 43           44  Sometimes I think it's good for me to leave ho...
# 44           45  I'd rather stay silent than discuss issues wit...
# 45           46  Even if I'm right in the discussion, I stay si...
# 46           47  When I discuss problems with my spouse, I stay...
# 47           48                   I feel right in our discussions.
# 48           49  I have nothing to do with what I've been accus...
# 49           50  I'm not actually the one who's guilty about wh...
# 50           51  I'm not the one who's wrong about problems at ...
# 51           52  I wouldn't hesitate to tell my spouse about he...
# 52           53  When I discuss things with my spouse, I remind...
# 53           54  I'm not afraid to tell my spouse about her/his...

# %%
feature = df.columns

# %%
imp_features = sorted(zip(rf.feature_importances_, feature), reverse=True)
imp_features = pd.DataFrame(imp_features)

# %%
imp_features = imp_features.rename(columns = { 0: 'importance_score', 1: 'atribute_id'})
imp_features['atribute_id'] = imp_features['atribute_id'].str.replace('Q', '').astype('int64')
imp_features.head(10)
# Out:
#    importance_score  atribute_id
# 0          0.119232           12
# 1          0.097749           19
# 2          0.092305           38
# 3          0.076656           17
# 4          0.075750           18
# 5          0.058211           40
# 6          0.051689           15
# 7          0.049754           36
# 8          0.049270           20
# 9          0.048986           16

# %%
merged_df = pd.merge(imp_features, question_data, on="atribute_id")
merged_df.head(10)
# Out:
#    importance_score  atribute_id  \
# 0          0.119232           12
# 1          0.097749           19
# 2          0.092305           38
# 3          0.076656           17
# 4          0.075750           18
# 5          0.058211           40
# 6          0.051689           15
# 7          0.049754           36
# 8          0.049270           20
# 9          0.048986           16
#
#                                          description
# 0  My spouse and I have similar values in terms o...
# 1  My spouse and I have similar ideas about how r...
# 2       I hate my spouse's way of opening a subject.
# 3  We share the same views about being happy in o...
# 4  My spouse and I have similar ideas about how m...
# 5  We're just starting a discussion before I know...
# 6  My dreams with my spouse are similar and harmo...
# 7          I can be humiliating when we discussions.
# 8      My spouse and I have similar values in trust.
# 9  I'm compatible with my spouse about what love ...

# %%
feature_questions = []
i=0
for i in range(len(merged_df)):
    question = merged_df.iloc[i, 2]
    feature_questions.append(question)

feature_questions
# Out:
# ['My spouse and I have similar values in terms of personal freedom.',
#  'My spouse and I have similar ideas about how roles should be in marriage.',
#  "I hate my spouse's way of opening a subject.",
#  'We share the same views about being happy in our life with my spouse.',
#  'My spouse and I have similar ideas about how marriage should be.',
#  "We're just starting a discussion before I know what's going on.",
#  'My dreams with my spouse are similar and harmonious.',
#  'I can be humiliating when we discussions.',
#  'My spouse and I have similar values in trust.',
#  "I'm compatible with my spouse about what love should be.",
#  "I know my spouse's basic anxieties.",
#  'I enjoy traveling with my spouse.',
#  'I think that one day in the future, when I look back, I will see that my spouse and I have been in harmony with each other.',
#  "I know my spouse's hopes and wishes.",
#  'When I talk to my spouse about something, my calm suddenly breaks.',
#  "I have knowledge of my spouse's inner world.",
#  "I know my spouse's friends and their social relationships.",
#  'I use offensive expressions during our discussions.',
#  'I know exactly what my spouse likes.',
#  "Sometimes I think it's good for me to leave home for a while.",
#  'Most of our goals for people (children, friends, etc.) are the same.',
#  'I insult my spouse during our discussions.',
#  'When I discuss with my spouse, to contact him will eventually work.',
#  'If one of us apologizes when our discussion deteriorates, the discussion ends.',
#  'I know we can ignore our differences, even if things get hard sometimes.',
#  'My discussions with my spouse are not calm.',
#  'Most of my goals are common with my spouse.',
#  'I know my spouse very well.',
#  "I know what my spouse's current sources of stress are.",
#  'I enjoy our holidays with my spouse.',
#  'Our discussions often occur suddenly.',
#  "I have nothing to do with what I've been accused of.",
#  'When we need it, we can take our discussions from the beginning and correct it.',
#  "When discussing problems with my spouse, I usually use expressions such as ‘you always’ or ‘you never'.",
#  "I use negative statements about my spouse's personality during our discussions.",
#  'When I discuss things with my spouse, I remind my spouse of her/his inadequacy.',
#  "I wouldn't hesitate to tell my spouse about her/his inadequacy.",
#  "I'm not actually the one who's guilty about what I'm accused of.",
#  'The time I spend with my spouse is special for us.',
#  'I mostly stay silent to calm the environment a little bit.',
#  'My spouse and I have a similar sense of entertainment.',
#  "I'm not the one who's wrong about problems at home.",
#  "When I argue with my spouse, I only go out and I don't say a word.",
#  'When I discuss problems with my spouse, I stay silent because I am afraid of not being able to control my anger.',
#  "I'd rather stay silent than discuss issues with my spouse.",
#  'We are like two strangers who share the same environment at home rather than family.',
#  "We don't have time at home as partners.",
#  'I feel right in our discussions.',
#  'I know how my spouse wants to be taken care of when she/he is sick.',
#  "I'm not afraid to tell my spouse about her/his incompetence.",
#  'I can tell you what kind of stress my spouse is facing in her/his life.',
#  'I feel aggressive when I argue with my spouse.',
#  "Even if I'm right in the discussion, I stay silent to hurt my spouse.",
#  "I know my spouse's favorite food."]
